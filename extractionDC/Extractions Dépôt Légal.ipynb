# %%
import pandas as pd
import SRUextraction as sru
from lxml import etree
from stdf import *

# %%
corpus = {"Livres": "Books"}
metas = ["ARK", "title", "subject", "description", "source", "language", "relation", "coverage", "creator", "contributor", "publisher", "rights", "date", "type", "format", "identifier"]
report = create_file(f"BibNatFra - Livres.txt", metas)
query = f"bib.frenchNationalBibliography any {corpus['Livres']}"
results = sru.SRU_result(query, parametres={"recordSchema": "dublincore", "maximumRecords": "500"})
"""
for record in results.dict_records:
    xml_record = results.dict_records[record]
    print(etree.tostring(xml_record))"""



for record in results.dict_records:
    xml_record = results.dict_records[record]
    row = [record]
    for meta_name in metas:
        info = xml_record.xpath(f".//*[local-name()='{meta_name}']", namespaces={"dc": "http://purl.org/dc/elements/1.1/", "oai_dc": "http://www.openarchives.org/OAI/2.0/oai_dc/"})
        info = [el.text for el in info]
        info = " ; ".join(info)
        row.append(info)
    line2report(row, report, display=False)
	
df = pd.read_csv(report.name, encoding="utf-8", delimiter="\t")
df.to_excel(report.name.replace(".txt", ".xlsx"))
# Out:
# ['ARK', 'title', 'subject', 'description', 'source', 'language', 'relation', 'coverage', 'creator', 'contributor', 'publisher', 'rights', 'date', 'type', 'format', 'identifier']

# %%
report_name = "BibNatFra - Livres.txt"
df = pd.read_csv(report_name, encoding="utf-8", delimiter="\t")
df.to_excel(report_name.replace(".txt", ".xlsx"))

# %%
df
# Out:
#                         ARK  \
# ark:/12148/cb34347868s  NaN
# ark:/12148/cb369464124  NaN
# ark:/12148/cb36595058f  NaN
# ark:/12148/cb343475590  NaN
# ark:/12148/cb375831701  NaN
# ...                     ...
# ark:/12148/cb342986868  NaN
# ark:/12148/cb343129865  NaN
# ark:/12148/cb343139465  NaN
# ark:/12148/cb388797263  NaN
# ark:/12148/cb36946786h  NaN
#
#                                                                     title  \
# ark:/12148/cb34347868s                                          Logifirst
# ark:/12148/cb369464124                                        Orientateur
# ark:/12148/cb36595058f                                           Anatomie
# ark:/12148/cb343475590                            Les carnets de l'adepte
# ark:/12148/cb375831701                     Glorieux cavaliers de Napoléon
# ...                                                                   ...
# ark:/12148/cb342986868  Tourisme, prévisions, perspectives, prospectiv...
# ark:/12148/cb343129865                Peutit Keupon / par Tapage nocturne
# ark:/12148/cb343139465  L'Exécutif en France / Compagnie européenne d'...
# ark:/12148/cb388797263           DESCF, manuel & applications (Éd. 2002)
# ark:/12148/cb36946786h                        Chimie analytique (3e éd.)
#
#                        subject                        description  source  \
# ark:/12148/cb34347868s     NaN                                NaN     NaN
# ark:/12148/cb369464124     NaN                                NaN     NaN
# ark:/12148/cb36595058f     NaN                                NaN     NaN
# ark:/12148/cb343475590     NaN                                NaN     NaN
# ark:/12148/cb375831701     NaN                                NaN     NaN
# ...                        ...                                ...     ...
# ark:/12148/cb342986868     NaN                                NaN     NaN
# ark:/12148/cb343129865     NaN                                NaN     NaN
# ark:/12148/cb343139465     NaN                                NaN     NaN
# ark:/12148/cb388797263     NaN            Collection : Expert sup     NaN
# ark:/12148/cb36946786h     NaN  Collection : Abrégés de pharmacie     NaN
#
#                               language  relation  coverage  \
# ark:/12148/cb34347868s  fre ; français       NaN       NaN
# ark:/12148/cb369464124  fre ; français       NaN       NaN
# ark:/12148/cb36595058f  fre ; français       NaN       NaN
# ark:/12148/cb343475590  fre ; français       NaN       NaN
# ark:/12148/cb375831701  fre ; français       NaN       NaN
# ...                                ...       ...       ...
# ark:/12148/cb342986868  fre ; français       NaN       NaN
# ark:/12148/cb343129865  fre ; français       NaN       NaN
# ark:/12148/cb343139465  fre ; français       NaN       NaN
# ark:/12148/cb388797263  fre ; français       NaN       NaN
# ark:/12148/cb36946786h  fre ; français       NaN       NaN
#
#                                                                   creator  \
# ark:/12148/cb34347868s                                                NaN
# ark:/12148/cb369464124                                                NaN
# ark:/12148/cb36595058f                                                NaN
# ark:/12148/cb343475590                                                NaN
# ark:/12148/cb375831701                                                NaN
# ...                                                                   ...
# ark:/12148/cb342986868         Baretje, René (1933-....). Auteur du texte
# ark:/12148/cb343129865          Tapage nocturne (Auteur). Auteur du texte
# ark:/12148/cb343139465  Compagnie européenne d'édition et de publicati...
# ark:/12148/cb388797263                                                NaN
# ark:/12148/cb36946786h                                                NaN
#
#                        contributor  \
# ark:/12148/cb34347868s         NaN
# ark:/12148/cb369464124         NaN
# ark:/12148/cb36595058f         NaN
# ark:/12148/cb343475590         NaN
# ark:/12148/cb375831701         NaN
# ...                            ...
# ark:/12148/cb342986868         NaN
# ark:/12148/cb343129865         NaN
# ark:/12148/cb343139465         NaN
# ark:/12148/cb388797263         NaN
# ark:/12148/cb36946786h         NaN
#
#                                                                 publisher  \
# ark:/12148/cb34347868s                         Institut First (Compiègne)
# ark:/12148/cb369464124                                    Essalam (Paris)
# ark:/12148/cb36595058f               Flammarion médecine sciences (Paris)
# ark:/12148/cb343475590                                   Ed. BAGI (Paris)
# ark:/12148/cb375831701                                     Atlas (Evreux)
# ...                                                                   ...
# ark:/12148/cb342986868  Centre des hautes études touristiques (Aix-en-...
# ark:/12148/cb343129865  BP 47, 76802 Cedex (Saint-Etienne-du-Rouvray) ...
# ark:/12148/cb343139465  Compagnie européenne d'éditions et publication...
# ark:/12148/cb388797263                                      Dunod (Paris)
# ark:/12148/cb36946786h                                     Masson (Paris)
#
#                                                                    rights  \
# ark:/12148/cb34347868s  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb369464124  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb36595058f  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb343475590  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb375831701  Catalogue en ligne de la Bibliothèque national...
# ...                                                                   ...
# ark:/12148/cb342986868  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb343129865  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb343139465  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb388797263  Catalogue en ligne de la Bibliothèque national...
# ark:/12148/cb36946786h  Catalogue en ligne de la Bibliothèque national...
#
#                         date                                 type  \
# ark:/12148/cb34347868s  199   texte imprimé ; printed text ; text
# ark:/12148/cb369464124  1997  texte imprimé ; printed text ; text
# ark:/12148/cb36595058f  1998  texte imprimé ; printed text ; text
# ark:/12148/cb343475590  1996  texte imprimé ; printed text ; text
# ark:/12148/cb375831701  2001  texte imprimé ; printed text ; text
# ...                      ...                                  ...
# ark:/12148/cb342986868  1980  texte imprimé ; printed text ; text
# ark:/12148/cb343129865  1986  texte imprimé ; printed text ; text
# ark:/12148/cb343139465  1989  texte imprimé ; printed text ; text
# ark:/12148/cb388797263  2002  texte imprimé ; printed text ; text
# ark:/12148/cb36946786h  1999  texte imprimé ; printed text ; text
#
#                                               format  \
# ark:/12148/cb34347868s              disquette ; 9 cm
# ark:/12148/cb369464124                         20 cm
# ark:/12148/cb36595058f                         19 cm
# ark:/12148/cb343475590                         22 cm
# ark:/12148/cb375831701                         30 cm
# ...                                              ...
# ark:/12148/cb342986868                         21 cm
# ark:/12148/cb343129865  Ill., couv. ill. ; 8 x 21 cm
# ark:/12148/cb343139465                         32 cm
# ark:/12148/cb388797263                         24 cm
# ark:/12148/cb36946786h                         21 cm
#
#                                                             identifier
# ark:/12148/cb34347868s  http://catalogue.bnf.fr/ark:/12148/cb34347868s
# ark:/12148/cb369464124  http://catalogue.bnf.fr/ark:/12148/cb369464124
# ark:/12148/cb36595058f  http://catalogue.bnf.fr/ark:/12148/cb36595058f
# ark:/12148/cb343475590  http://catalogue.bnf.fr/ark:/12148/cb343475590
# ark:/12148/cb375831701  http://catalogue.bnf.fr/ark:/12148/cb375831701
# ...                                                                ...
# ark:/12148/cb342986868  http://catalogue.bnf.fr/ark:/12148/cb342986868
# ark:/12148/cb343129865  http://catalogue.bnf.fr/ark:/12148/cb343129865
# ark:/12148/cb343139465  http://catalogue.bnf.fr/ark:/12148/cb343139465
# ark:/12148/cb388797263  http://catalogue.bnf.fr/ark:/12148/cb388797263
# ark:/12148/cb36946786h  http://catalogue.bnf.fr/ark:/12148/cb36946786h
#
# [484 rows x 16 columns]
