# %% [markdown]
# cf. https://graphviz.readthedocs.io/en/stable/manual.html
#
# Installation de graphviz:
# * comme librairie Python
# * comme exécutable Windows, Ubuntu ou Marc

# %%
import graphviz

# %%
dot = graphviz.Digraph('round-table', comment='The Round Table')  


# Add nodes and edges to the graph object using its node() and edge() or edges() methods:

dot.node('A', 'King Arthur')  
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')
dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

# %%
dot

# %%
dot = graphviz.Digraph('round-table', comment='The Round Table')  


# Add nodes and edges to the graph object using its node() and edge() or edges() methods:

dot.node('A', 'King Arthur')  
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')
dot.edges(['AB', 'AL', "BL", "LB"])
# dot.edge('B', 'L', constraint='false')

# %%
dot
